# %% [markdown]
# 18.04.2026 - İYC
# Öğr. Gör. Ali Çetinkaya
# Algoritmalar,Veri Yapıları & Yapay Zeka Uygulamaları Atölyesi
# # Veriyi işle, geleceği kodla!

# %%
print("merhaba hayat")
# Out:
# merhaba hayat

# %%
import sys #import komutu python dilinde kütüphane eklemek için kullanılır.
print (sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/GoogleColab')
# !pwd #ilk kod bloğunun çıktısını bize veren kod blogudur.
# Out:
# /content/drive/My Drive/GoogleColab
